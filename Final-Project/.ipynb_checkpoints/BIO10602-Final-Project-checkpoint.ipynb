# %%
import matplotlib.pyplot as plt

labels = ['0', '30', '50']
variants = [209106, 186935, 142725]

fig, ax = plt.subplots()

plt.title("Minimum Phred Score versus Variants Obtained")
plt.xlabel("Minimum Phred Score")
plt.ylabel("Variants")

ax.bar(labels, variants)

plt.show()

# %%
import matplotlib.pyplot as plt

observed = [16616, 12132, 9760, 9120, 9300, 8831, 9341, 7980, 8236, 10555, 10390, 9202, 5368, 5659, 6124, 7850, 8127, 4329, 7787, 5621, 3023, 4957, 3876, 170]
